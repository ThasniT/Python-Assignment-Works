# %% [markdown]
# # 1. What exactly is [ ]?

# %% [markdown]
# Python has a great built-in list type named "list". List literals are written within square brackets [ ]
#
# Index brackets ([ ]) have many uses in Python. First, they are used to define "list literals," allowing you to declare a list and its contents in your program. Index brackets are also used to write expressions that evaluate to a single item within a list, or a single character in a string
#
# Lists are used to store multiple items in a single variable.Lists are created using square brackets:

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
x=[ 1,2,3,4,5]
print(x)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # 2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)

# %%
spam = [2,4,6,8,10]
spam[2]='hello'
print(spam)
# Out:
# [2, 4, 'hello', 8, 10]

# %% [markdown]
# # 3. Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.

# %%
spam = ['a','b','c','d']

# %% [markdown]
# # What is the value of spam[int(int('3' * 2) / 11)]?

# %%
spam[int(int('3' * 2) / 11)]
# Out:
# 'd'

# %% [markdown]
# # 4. What is the value of spam[-1]?

# %%
spam[-1]
# Out:
# 'd'

# %% [markdown]
# spam[-1] means,we are trying to access the elements in the reverse order.Index
#   [ -1 ] means the last element

# %% [markdown]
# # 5. What is the value of spam[:2]?

# %%
spam[:2]
# Out:
# ['a', 'b']

# %% [markdown]
# # 6. Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.

# %%
bacon = [3.14, 'cat', 11, 'cat', True]

# %% [markdown]
# # What is the value of bacon.index('cat')?

# %%
bacon.index('cat')
# Out:
# 1

# %%
bacon.index(True)
# Out:
# 4

# %% [markdown]
# # 7. How does bacon.append(99) change the look of the list value in bacon?

# %%
bacon.append(99)
print(bacon)
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# 99 is added at the end of the list bacon

# %% [markdown]
# # 8. How does bacon.remove('cat') change the look of the list in bacon?

# %%
bacon.remove('cat')
print(bacon)
# Out:
# [3.14, 11, True, 99]

# %% [markdown]
# 'cat' is removed from the list bacon

# %% [markdown]
# # 9. What are the list concatenation and list replication operators?

# %% [markdown]
# As with strings, we can use the operators   **+ and ***     to concatenate and replicate lists.
#
# When + appears between two lists, the expression will be evaluated as a new list that contains the elements from both lists. The elements in the list on the left of + will appear first, and the elements on the right will appear last.
#
# When * appears between a list and an integer, the expression will be evaluated as a new list that consists of several copies of the original list concatenated together. The number of copies is set by the integer.

# %%
letter_list = ['A', 'B', 'C']
number_list = [1, 2, 3]

print(letter_list + number_list)
print(number_list * 4)
# Out:
# ['A', 'B', 'C', 1, 2, 3]
# [1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3]

# %% [markdown]
# # 10. What is difference between the list methods append() and insert()?

# %% [markdown]
# **Append**
#
# It adds an element at the end of the list. The argument passed in the append function is added as a single element at end of the list and the length of the list is increased by 1.
#
# Syntax
#
# list_name.append(element)
#
# The difference between the two methods is that  **append()** adds an item to the end of a list, whereas  **insert()** inserts and item in a specified position in the list.

# %%
numbers = [1,2,3,4,5]
numbers.append(6)
print(numbers)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# **Insert**
#
# This method can be used to insert a value at any desired position. It takes two arguments-element and the index at which the element has to be inserted.
#
# Syntax:
#
# list_name(index,element)
#
# The element can be a string, object, or integer.

# %%
numbers.insert(0,0)   #Insert 0 at index 0

# %%
print(numbers)
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
numbers.insert(7,8)
print(numbers)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 8]

# %% [markdown]
# # 11. What are the two methods for removing items from a list?

# %% [markdown]
# ## **Remove Specified Item**
#
# The remove() method removes the specified item.

# %%
# Remove "banana":

thislist = ["apple", "banana", "cherry"]
thislist.remove("banana")
print(thislist)

# %% [markdown]
# ## **Remove Specified Index**
#
# The pop() method removes the specified index.

# %%
# Remove the second item:

thislist = ["apple", "banana", "cherry"]
thislist.pop(1)
print(thislist)

# %% [markdown]
# If you do not specify the index, the pop() method removes the last item.

# %%
# Remove the last item:

thislist = ["apple", "banana", "cherry"]
thislist.pop()
print(thislist)

# %% [markdown]
# The del keyword also removes the specified index:

# %%
# Remove the first item:

thislist = ["apple", "banana", "cherry"]
del thislist[0]
print(thislist)

# %% [markdown]
# The del keyword can also delete the list completely.

# %%
# Delete the entire list:

thislist = ["apple", "banana", "cherry"]
del thislist

# %% [markdown]
# ## **Clear the List**
#
# The clear() method empties the list.
#
# The list still remains, but it has no content.

# %%
# Clear the list content:

thislist = ["apple", "banana", "cherry"]
thislist.clear()
print(thislist)

# %% [markdown]
# # 12. Describe how list values and string values are identical.

# %% [markdown]
# The similarity between Lists and Strings in Python is that both are sequences.
#
# Both strings and lists have lengths: a string's length is the number of characters in the string; a list's length is the number of items in the list. Each character in a string as well as each item in a list has a position, also called an index.

# %% [markdown]
# # 13. What's the difference between tuples and lists?

# %% [markdown]
# List and Tuple in Python are the classes of Python Data Structures. The list is dynamic, whereas the tuple has static characteristics. This means that lists can be modified whereas tuples cannot be modified, the tuple is faster than the list because of static in nature. Lists are denoted by the square brackets but tuples are denoted as parenthesis.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 14. How do you type a tuple value that only contains the integer 42?

# %%
m = (42, )    # Trailing comma is mandatory for tuple
print(m)
# Out:
# (42,)

# %% [markdown]
# # 15. How do you get a list value's tuple form? How do you get a tuple value's list form?

# %% [markdown]
# Python language consists of various built-in functions to ease your programming and the tuple() function is one of them. tuple () function can take any iterable as an argument and convert it into a tuple object. As you wish to convert a python list to a tuple, you can pass the entire list as a parameter within the tuple() function, and it will return the tuple data type as an output.

# %%
numbers = [1,2,3,4,5]
tuple1 =tuple(numbers)
print(tuple1)
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# If we want to convert tuple to list,pass it as an argument to list function.

# %%
numbers = [1,2,3,4,5]
list1 = list(numbers)
print(list1)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # 16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?

# %% [markdown]
# Variables will contain references to list values rather than list values themselves. But for strings and integer values, variables simply contain the string or integer value. Python uses references whenever variables must store values of mutable data types, such as lists or dictionaries. For values of immutable data types such as strings, integers, or tuples, Python variables will store the value itself.
#
# Although Python variables technically contain references to list or dictionary values, people often casually say that the variable contains the list or dictionary.

# %% [markdown]
# # 17. How do you distinguish between copy.copy() and copy.deepcopy()?

# %% [markdown]
# Although passing around references is often the handiest way to deal with lists and dictionaries, if the function modifies the list or dictionary that is passed, you may not want these changes in the original list or dictionary value. For this, Python provides a module named copy that provides both the copy() and deepcopy() functions. The first of these, copy.copy(), can be used to make a duplicate copy of a mutable value like a list or dictionary, not just a copy of a reference.

# %%
import copy
spam = ['A', 'B', 'C', 'D']
cheese = copy.copy(spam)
cheese[1] = 42
print(spam)
print(cheese)
# Out:
# ['A', 'B', 'C', 'D']
# ['A', 42, 'C', 'D']

# %% [markdown]
# Now the spam and cheese variables refer to separate lists, which is why only the list in cheese is modified when you assign 42 at index 1. As you can see in below  Figure, the reference ID numbers are no longer the same for both variables because the variables refer to independent lists.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# If the list you need to copy contains lists, then use the copy.deepcopy() function instead of copy.copy(). The deepcopy() function will copy these inner lists as well.
