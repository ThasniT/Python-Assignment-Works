# %% [markdown]
# # 1. What does an empty dictionary's code look like?

# %%
#To create an empty dictionary, the dictionary should be set to {}.

items = {}

# %%
# Python code to demonstrate use of
# {} symbol to initialize dictionary
emptyDict = {}

# print dictionary
print(emptyDict)

# print length of dictionary
print("Length:", len(emptyDict))

# print type
print(type(emptyDict))
# Out:
# {}
# Length: 0
# <class 'dict'>

# %% [markdown]
# # 2. What is the value of a dictionary value with the key 'foo' and the value 42?

# %%
emp = { 'foo' : 42 }

print(emp['foo'])

print(emp)
# Out:
# 42
# {'foo': 42}

# %% [markdown]
# # 3. What is the most significant distinction between a dictionary and a list?

# %% [markdown]
# Lists are used to store the data, which should be ordered and sequential. On the other hand, dictionary is used to store large amounts of data for easy and quick access. List is ordered and mutable, whereas dictionaries are unordered and mutable.
#
# Lists are orders, mutable, and can contain duplicate values. Dictionaries are unordered and mutable but they cannot contain duplicate keys.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 4. What happens if you try to access spam['foo'] if spam is {'bar': 100}?

# %%
spam = { 'bar' : 100 }
print(spam['foo'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-25ab6e2c47eb> in <cell line: 2>()
#       1 spam = { 'bar' : 100 }
# ----> 2 print(spam['foo'])
#
# KeyError: 'foo'

# %% [markdown]
# It will show key error as 'foo' is not present in the dictionary.

# %% [markdown]
# # 5. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys()?

# %% [markdown]
# There is no difference. The in operator checks whether a value exists as a key in the dictionary.
#
# 'cat' in spam checks whether there is a 'cat' key in the dictionary, and 'cat' in spam.keys() checks whether there is a key 'cat' in spam.

# %%
spam = { 'cat': 10 }

'cat' in spam    # A value exists as a key in the dictionary.
# Out:
# True

# %%
'cat' in spam.keys()       #Checks whether there is a key 'cat' in spam.
# Out:
# True

# %% [markdown]
# # 6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.values()?

# %% [markdown]
# There is a difference. The in operator checks whether a value exists as 'cat' in the dictionary.

# %% [markdown]
# 'cat' in spam checks whether there is a 'cat' key in the dictionary, while 'cat' in spam.values() checks whether there is a value 'cat' for one of the keys in spam.

# %%
spam = { 'cat': 10 }

'cat' in spam
# Out:
# True

# %%
'cat' in spam.values()
# Out:
# False

# %% [markdown]
# # 7. What is a shortcut for the following code?
#
# if 'color' not in spam:
#
#
# spam['color'] = 'black'

# %% [markdown]
# **The** **setdefault() Method**

# %% [markdown]
# You’ll often have to set a value in a dictionary for a certain key only if that key does not already have a value. The code looks something like this:

# %%
spam = {'name': 'Pooja', 'age': 5}

if 'color' not in spam:
    spam['color'] = 'black'

# %% [markdown]
# The setdefault() method offers a way to do this in one line of code. The first argument passed to the method is the key to check for, and the second argument is the value to set at that key if the key does not exist. If the key does exist, the setdefault() method returns the key’s value.

# %%
spam.setdefault('color', 'black')
# Out:
# 'black'

# %% [markdown]
# When setdefault() is called, the dictionary in spam changes to {'color': 'black', 'age': 5, 'name': 'Pooka'}. The method returns the value 'black' because this is now the value set for the key 'color'.

# %% [markdown]
# # 8. How do you "pretty print" dictionary values using which module and function?

# %% [markdown]
# "Prettyprint” is defined as a process where the source code or any other item is displayed in an attractively presentable way.
#
# The pprint module provides a capability to “pretty-print” arbitrary Python data structures in a form which can be used as input to the interpreter.
#
# We can pretty print dict Python by importing the 'pprint' module in Python which gives the capability to “pretty-print” random data structures in a much more presentable form that can also be used as input to the interpreter.

# %%
pprint.pprint()
