# %% [markdown]
# #                                                        Assignment  I
#
#
# # Object-Oriented Programming (OOP)

# %% [markdown]
# # 1. What is the primary goal of Object-Oriented Programming (OOP)?

# %% [markdown]
# ### Object Oriented programming language is based on classes and objects.
# It is used to structure a program into a simple, reusable piece of code.
# The entire software program runs by having multiple objects interact with objects to create large programs.
#
# Goals of object-oriented programming language :
#
#  1. **Adaptability** - means the software may run on different generations and grows over a long lifetime.
#  2. To  **reuse** the code in which child classes uses the properties of the base class.
#  3. To **hold entire data** into a single object such that it would be easy to pass this to other methods and objects.
#  4. **Multiprocessing** is also in object-oriented programming.
#  5. **Binding** of data to avoid data loss.
#  6. **Robustness** - it means complex programs should operate correctly.
#
#  The three primary goals of  Object Oriented Programming are Robustness, Adaptability, and Reusability.

# %% [markdown]
# # 2. What is an object in Python?

# %% [markdown]
# Objects are the instances of a particular class.  Objects are different copies of the class with some actual values.An Object is an instance of a Class. A class is like a blueprint while an instance is a copy of the class with actual values. Python is an object-oriented programming language that stresses objects i.e. it mainly emphasizes functions.
#
# An object is called an instance of a class. For example, suppose Bike is a class then we can create objects like bike1, bike2, etc from the class.
# Everything is in Python treated as an object, including variable, function, list, tuple, dictionary, set, etc. Every object belongs to its class. For example - An integer variable belongs to integer class. An object is a real-life entity. An object is the collection of various data and functions that operate on those data. An object contains the following properties:
#
#
# **State**-  The attributes of an object represents its state. It also reflects the properties of an object.
#
# **Behavior**- The method of an object represents its behavior.
#
# **Identity**- Each object must be uniquely identified and allow interacting with the other objects.

# %% [markdown]
# # 3. What is a class in Python?

# %% [markdown]
# Class is a blueprint which defines some properties and behaviors. A class is a code template for creating objects. An object is an instance of a class which has those properties and behaviours attached. A class is not allocated memory when it is defined. An object is allocated memory when it is created. Class is a logical entity whereas objects are physical entities.Classes provide a means of bundling data and functionality together. Creating a new class creates a new type of object, allowing new instances of that type to be made.In Python, a class is a user-defined data type that contains both the data itself and the methods that may be used to manipulate it. In a sense, classes serve as a template to create objects. They provide the characteristics and operations that the objects will employ.
#
# Suppose a class is a prototype of a building. A building contains all the details about the floor, rooms, doors, windows, etc. we can make as many buildings as we want, based on these details. Hence, the building can be seen as a class, and we can create as many objects of this class.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
#
# Ref:https://pynative.com/python-classes-and-objects/

# %% [markdown]
# # 4.  What are attributes and methods in a class?

# %% [markdown]
# # i) Class Attributes
#
# In Class, attributes can be defined into two parts:
#
#
#
# *   **Instance variables:** The instance variables are attributes attached to an instance of a class. We define instance variables in the constructor ( the __init__() method of a class).
#
#
#
# *   **Class Variables:** A class variable is a variable that is declared inside of class, but outside of any instance method or __init__() method.
#
#
#
# Objects do not share instance attributes. Instead, every object has its copy of the instance attribute and is unique to each object.
#
# All instances of a class share the class variables. However, unlike instance variables, the value of a class variable is not varied from object to object.
#
# Only one copy of the static variable will be created and shared between all objects of the class.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Accessing properties and assigning values
#
#
# An instance attribute can be accessed or modified by using the dot notation:
#
#                    instance_name.attribute_name.
#
#
# A class variable is accessed or modified using the class name
#
#                    class_name.attribute_name.

# %% [markdown]
# # ii)  Class Methods
#
#
# In Object-oriented programming, Inside a Class, we can define the following three types of methods.
#
#
# **Instance method:**  Used to access or modify the object state. If we use instance variables inside a method, such methods are called instance methods.
#
# **Class method:**  Used to access or modify the class state. In method implementation, if we use only class variables, then such type of methods we should declare as a class method.
#
# **Static method:**  It is a general utility method that performs a task in isolation. Inside this method, we don’t use instance or class variable because this static method doesn’t have access to the class attributes.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 5. What is the purpose of the self parameter in Python class methods?

# %% [markdown]
# The self parameter is a reference to the current instance of the class, and is used to access variables that belongs to the class.
#
# It does not have to be named self , you can call it whatever you like, but it has to be the first parameter of any function in the class:

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  #method 1
  def display(self):
    print(f"my name is {self.name} and age is {self.age}")

# %%
class Person:
  def __init__(abc, name, age):    #using abc instead of self but it should be the first argument
    abc.name = name
    abc.age = age

  def display(xyz):                 #using xyz instead of self but it should be the first argument
    print("Hello my name is " + xyz.name)

p1 = Person("John", 36)
p1.display()
# Out:
# Hello my name is John

# %% [markdown]
# # 6. For a library management system, you have to design the "Book" class with OOP principles in mind. The “Book” class will have following attributes:
#
#       a. title: Represents the title of the book.
#
#       b. author: Represents the author(s) of the book.
#
#       c. isbn: Represents the ISBN (International Standard Book Number) of the book.
#
#       d. publication_year: Represents the year of publication of the book.
#
#       e. available_copies: Represents the number of copies available for checkout.
#
# The class will also include the following methods:
#
#
#      a. check_out(self): Decrements the available copies by one if there are copies available for checkout.
#
#      b. return_book(self): Increments the available copies by one when a book is
#        returned.
#
#      c. display_book_info(self): Displays the information about the book,
#         including its attributes and the number of available copies.

# %%
class Book:
   def __init__(self,title,author,isbn,publication_year,available_copies):
          self.title =title                        # Represents the title of the book.
          self.author =author                      # Represents the author(s) of the book.
          self.isbn =isbn                          # Represents the ISBN (International Standard Book Number) of the book.
          self.publication_year =publication_year  # Represents the year of publication of the book.
          self.available_copies =available_copies  # Represents the number of copies available for checkout.




   def check_out(self):            #Decrements the available copies by one if there are copies available for checkout.
          print(f"No of copies available before checkout of book titled {self.title} with  isbn {self.isbn} = {self.available_copies}")
          if self.available_copies != 0:
             self.available_copies=self.available_copies-1
             print(f"No of copies available before checkout of book titled {self.title} with  isbn {self.isbn} = {self.available_copies}")
          else:
             print(f"Sorry ,there are no copies available to check out!!!Better luck next time")





   def return_book(self):          #Increments the available copies by one when a book is returned.
           print(f"No of copies available before returning  of book titled {self.title} with  isbn {self.isbn} = {self.available_copies}")
           self.available_copies=self.available_copies+1
           print(f"No of copies available after returning of book titled {self.title} with  isbn {self.isbn} = {self.available_copies}")




   def display_book_info(self):    #Displays the information about the book, including its attributes and the number of available copies
        print(f"The book titled Python programming which was published in the year {self.publication_year} is authored by {self.author}.The isbn number of that book is {self.isbn}.There are {self.available_copies} copies of that book are available in the library.")




book = Book('Python','Ravi',1122,2023,5)    #Class object creation
book.display_book_info()
book.check_out()
book.return_book()
# Out:
# The book titled Python programming which was published in the year 2023 is authored by Ravi.The isbn number of that book is 1122.There are 5 copies of that book are available in the library.
# No of copies available before checkout of book titled Python with  isbn 1122 = 5
# No of copies available before checkout of book titled Python with  isbn 1122 = 4
# No of copies available before returning  of book titled Python with  isbn 1122 = 4
# No of copies available after returning of book titled Python with  isbn 1122 = 5

# %% [markdown]
# # 7. For a ticket booking system, you have to design the "Ticket" class with OOP principles in mind. The “Ticket” class should have the following attributes:
#
#
#     a. ticket_id: Represents the unique identifier for the ticket.
#     b. event_name: Represents the name of the event.
#     c. event_date: Represents the date of the event.
#     d. venue: Represents the venue of the event.
#     e. seat_number: Represents the seat number associated with the ticket.
#     f. price: Represents the price of the ticket.
#     g. is_reserved: Represents the reservation status of the ticket.
#
# The class also includes the following methods:
#
#     a. reserve_ticket(self): Marks the ticket as reserved if it is not already
#        reserved.
#     b. cancel_reservation(self): Cancels the reservation of the ticket if it is
#        already reserved.
#     c. display_ticket_info(self): Displays the information about the ticket,
#        including its  attributes and reservation status.

# %%
class Ticket:
    def __init__(self,ticket_id,event_name,event_date,venue,seat_number,price,is_reserved):
        self.ticket_id   = ticket_id          # Represents the unique identifier for the ticket.
        self.event_name  = event_name         # Represents the name of the event.
        self.event_date  = event_date         # Represents the date of the event.
        self.venue       =  venue             # Represents the venue of the event.
        self.seat_number = seat_number        # Represents the seat number associated with the ticket.
        self.price       = price              # Represents the price of the ticket.
        self.is_reserved = is_reserved        # Represents the reservation status of the ticket.

    def   reserve_ticket(self,id):            # Marks the ticket as reserved if it is not already reserved.
        if self.ticket_id == id and self.is_reserved == 'Not reserved':
           self.is_reserved='Reserved'
           print(f"Your ticket is reserved for the event {self.event_name} which is scheduled on {self.event_date} in venue {self.venue}.Your seat number is {self.seat_number}.Your ticket ID is {self.ticket_id} . Please note the price of the ticket Rs.{self.price}.")
        else:
           print("Sorry !!Please check once again.Your current status of ticket is already reserved")


    def   cancel_reservation(self,id):        # Cancels the reservation of the ticket if it is already reserved.
        if self.ticket_id == id and  self.is_reserved == 'Reserved':
           self.is_reserved ='Canceled'
           print(f"Your ticket is canceled for the event {self.event_name} which is scheduled on {self.event_date} in venue {self.venue}.Your ticket ID is {self.ticket_id} . Please note the price of the ticket Rs.{self.price} will be refunded to your account in another 24 hours.")
        else:
           print(f"Sorry we are unable to cancel the ticket. Please check your id and status again")

    def   display_ticket_info(self):          # Displays the information about the ticket, including its  attributes and reservation status.
        print(f"The status of the ticket having id {self.ticket_id} is {self.is_reserved} for the event {self.event_name} which is scheduled on {self.event_date}.The price of the ticket is {self.price}  ")



ticket = Ticket(123,"Water Dance",'12-07-2023','Cubbon Park',2,500,'Reserved')
ticket.display_ticket_info()
ticket.reserve_ticket(123)
ticket1 = Ticket(124,"Water Dance",'12-07-2023','Cubbon Park',2,500,'Not reserved')
ticket1.reserve_ticket(124)
ticket.cancel_reservation(123)
# Out:
# The status of the ticket having id 123 is Reserved for the event Water Dance which is scheduled on 12-07-2023.The price of the ticket is 500
# Sorry !!Please check once again.Your current status of ticket is already reserved
# Your ticket is reserved for the event Water Dance which is scheduled on 12-07-2023 in venue Cubbon Park.Your seat number is 2.Your ticket ID is 124 . Please note the price of the ticket Rs.500.
# Your ticket is canceled for the event Water Dance which is scheduled on 12-07-2023 in venue Cubbon Park.Your ticket ID is 123 . Please note the price of the ticket Rs.500 will be refunded to your account in another 24 hours.

# %% [markdown]
# # 8. You are creating a shopping cart for an e-commerce website. Using OOP to model the "ShoppingCart" functionality the class should contain following attributes and methods:
#
#      a. items: Represents the list of items in the shopping cart.
#
#
# The class also includes the following methods:
#
#
#     a. add_item(self, item): Adds an item to the shopping cart by appending it to the list of items.
#
#     b. remove_item(self, item): Removes an item from the shopping cart if it exists in the list.
#
#     c. view_cart(self): Displays the items currently present in the shopping cart.
#
#     d. clear_cart(self): Clears all items from the shopping cart by reassigning an empty list to the items attribute.

# %%
class ShoppingCart:

  def __init__(self):
      self.items=[]


  def add_item(self,item):    #Add only one item
      self.items.append(item)
      print(f"Your {item} is added to the shopping cart successfully")



  def remove_item(self,item):    # Remove only one item
      for i in self.items:
        if i==item:
           self.items.remove(item)
           print(f"Item {item} is removed successfully from the shopping cart")
           break
        else:
          print(f"Item {item} is not present in the list")



  def view_cart(self):       #View items in cart
      if self.items==[]:
        print("Your list is empty")
      else:
        print(f"The following are the items present in the shopping cart: ")
        for i in range(len(self.items)):
             print(f"The item {i+1} is {self.items[i]}")

  def clear_cart(self):     #Clear the items in cart
       self.items= []
       print(f"Your shopping cart is cleared")



  # Adding bulk items
  def add_itemsinbulk(self):
          n =int(input("Enter the number of  items to be added in the shopping cart "))
          for i in range(n):
              item =input("Enter the item to be added to the shopping cart")
              self.items.append(item)



shopping=ShoppingCart()
shopping.add_itemsinbulk()
shopping.view_cart()
shopping.add_item("Pencil")
shopping.view_cart()
shopping.add_item("Mobile")
shopping.remove_item("Pen")
shopping.view_cart()
shopping.clear_cart()
shopping.view_cart()
# Out:
# Enter the number of  items to be added in the shopping cart 2
# Enter the item to be added to the shopping cartPen
# Enter the item to be added to the shopping cartBook
# The following are the items present in the shopping cart:
# The item 1 is Pen
# The item 2 is Book
# Your Pencil is added to the shopping cart successfully
# The following are the items present in the shopping cart:
# The item 1 is Pen
# The item 2 is Book
# The item 3 is Pencil
# Your Mobile is added to the shopping cart successfully
# Item Pen is removed successfully from the shopping cart
# The following are the items present in the shopping cart:
# The item 1 is Book
# The item 2 is Pencil
# The item 3 is Mobile
# Your shopping cart is cleared
# Your list is empty

# %% [markdown]
# # 9. Imagine a school management system. You have to design the "Student" class using OOP concepts.The “Student” class has the following attributes:
#
#     a. name: Represents the name of the student.
#     b. age: Represents the age of the student.
#     c. grade: Represents the grade or class of the student.
#     d. student_id: Represents the unique identifier for the student.
#     e. attendance: Represents the attendance record of the student.
#
# The class should also include the following methods:
#
#     a. update_attendance(self, date, status): Updates the attendance record of
#        the student for a given date with the provided status (e.g., present or absent).
#     b. get_attendance(self): Returns the attendance record of the student.
#     c. get_average_attendance(self): Calculates and returns the average
#        attendance percentage of the student based on their attendance record.

# %%
class Student:

    def __init__(self,name,age,grade,student_id,attendance={}):

         self.name =name                                 #Represents the name of the student.
         self.age = age                                  #Represents the age of the student.
         self.grade  = grade                             #Represents the grade or class of the student.
         self.student_id = student_id                    #Represents the unique identifier for the student.
         self.attendance  =  {}                 #Represents the attendance record of the student.

    def update_attendance(self, date, status):             # Updates the attendance record of the student for a given date with the provided status (e.g., present or absent).
         self.attendance.update({date:status})


    def get_attendance(self):
        print(self.attendance.items())                     # Returns the attendance record of the student.
        for key , value in self.attendance.items():
           print(key,value)

    def get_average_attendance(self):               # Calculates and returns the average attendance percentage of the student based on their attendance record.

       for key, value in self.attendance.items():
            list1.append(value)
            totalclasses = len(list1)
            No_of_present = list1.count("P")
            percentageofattendance = No_of_present/totalclasses*100
       print(f"The attendance percentage of the student named {self.name} bearing id number {self.student_id} is {percentageofattendance} ")



std1=Student("Arav",20,"O",20123)
std1.update_attendance("12/07/2023","A")
std1.get_attendance()
std1.update_attendance("13/07/2023","P")
std1.get_attendance()
std1.update_attendance("14/07/2023","P")
std1.get_attendance()
std1.get_average_attendance()
# Out:
# dict_items([('12/07/2023', 'A')])
# 12/07/2023 A
# dict_items([('12/07/2023', 'A'), ('13/07/2023', 'P')])
# 12/07/2023 A
# 13/07/2023 P
# dict_items([('12/07/2023', 'A'), ('13/07/2023', 'P'), ('14/07/2023', 'P')])
# 12/07/2023 A
# 13/07/2023 P
# 14/07/2023 P
# The attendance percentage of the student named Arav bearing id number 20123 is 42.857142857142854
